# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2*np.pi,1000)
y = np.sin(x)
mean_absolute_v = np.mean(np.abs(y))
y_noisy = y + np.random.normal(loc=0.0, scale=0.02*mean_absolute_v,size=len(x))

# %%
plt.plot(x,y_noisy, label='noisy')
plt.plot(x,y, label='clean')
plt.legend()

# %%
firstD_clean = np.gradient(y,x)
firstD_noisy = np.gradient(y_noisy, x)
secondD_clean = np.gradient(firstD_clean, x)
secondD_noisy = np.gradient(firstD_noisy, x)

# %%
plt.plot(x, firstD_noisy,label='noisy')
plt.plot(x, firstD_clean,label='clean')
plt.legend()

# %%
plt.plot(x, secondD_noisy,label='noisy')
plt.plot(x, secondD_clean,label='clean')
plt.legend()

# %%
from DLTVR import DLTVR1D
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-ac940f780a99> in <module>
# ----> 1 from DLTVR import DLTVR1D
#
# ~/devel/deep_learning_total_variation_regularization/DLTVR/__init__.py in <module>
# ----> 1 from .dltvr1d import DLTVR1D
#
# ~/devel/deep_learning_total_variation_regularization/DLTVR/dltvr1d.py in <module>
#       5 """
#       6
# ----> 7 import tensorflow as tf
#       8 import numpy as np
#       9 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'tensorflow'
